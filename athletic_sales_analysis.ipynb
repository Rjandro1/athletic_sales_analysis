# %%
# Import Libraries and Dependencies
import pandas as pd

# %% [markdown]
# ### 1. Combine and Clean the Data
# #### Import CSVs

# %%
# Read the CSV files into DataFrames.
sales_2020_df = pd.read_csv("Resources/athletic_sales_2020.csv")
sales_2021_df = pd.read_csv("Resources/athletic_sales_2021.csv")

# %%
# Display the 2020 sales DataFrame
sales_2020_df
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0     Foot Locker      1185732       1/1/20  Northeast      New York
# 1     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3     Foot Locker      1185732       1/1/20  Northeast      New York
# 4     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 1292    West Gear      1128299     12/30/20       West    California
# 1293    West Gear      1128299     12/30/20       West    California
# 1294       Kohl's      1189833     12/30/20    Midwest     Minnesota
# 1295       Kohl's      1189833     12/30/20    Midwest     Minnesota
# 1296    West Gear      1128299     12/30/20       West    California
#
#                city                  product  price_per_unit  units_sold  \
# ...

# %%
# Display the 2021 sales DataFrame
sales_2021_df
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0       West Gear      1128299       1/1/21       West    California
# 1       West Gear      1128299       1/1/21       West    California
# 2          Kohl's      1189833       1/1/21    Midwest       Montana
# 3          Kohl's      1189833       1/1/21    Midwest       Montana
# 4       West Gear      1128299       1/1/21       West    California
# ...           ...          ...          ...        ...           ...
# 8341  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 8342  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 8343       Amazon      1185732     12/31/21  Northeast         Maine
# 8344       Amazon      1185732     12/31/21  Northeast         Maine
# 8345  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
#
#                city                  product  price_per_unit  units_sold  \
# ...

# %% [markdown]
# #### Check the data types of each DataFrame

# %%
# Check the 2020 sales data types.
sales_2021_df
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0       West Gear      1128299       1/1/21       West    California
# 1       West Gear      1128299       1/1/21       West    California
# 2          Kohl's      1189833       1/1/21    Midwest       Montana
# 3          Kohl's      1189833       1/1/21    Midwest       Montana
# 4       West Gear      1128299       1/1/21       West    California
# ...           ...          ...          ...        ...           ...
# 8341  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 8342  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 8343       Amazon      1185732     12/31/21  Northeast         Maine
# 8344       Amazon      1185732     12/31/21  Northeast         Maine
# 8345  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
#
#                city                  product  price_per_unit  units_sold  \
# ...

# %%
# Check the 2021 sales data types.
sales_2021_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8346 entries, 0 to 8345
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   retailer          8346 non-null   object
#  1   retailer_id       8346 non-null   int64
#  2   invoice_date      8346 non-null   object
#  3   region            8346 non-null   object
#  4   state             8346 non-null   object
#  5   city              8346 non-null   object
#  6   product           8346 non-null   object
#  7   price_per_unit    8346 non-null   int64
#  8   units_sold        8346 non-null   int64
#  9   total_sales       8346 non-null   int64
#  10  operating_profit  8346 non-null   float64
#  11  sales_method      8346 non-null   object
# dtypes: float64(1), int64(4), object(7)
# memory usage: 782.6+ KB

# %% [markdown]
# #### Combine the sales data by rows.

# %%
# Combine the 2020 and 2021 sales DataFrames on the rows and reset the index.
Combined_data_df = pd.concat([sales_2020_df, sales_2021_df], axis=0)
Combined_data_df
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0     Foot Locker      1185732       1/1/20  Northeast      New York
# 1     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3     Foot Locker      1185732       1/1/20  Northeast      New York
# 4     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 8341  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 8342  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 8343       Amazon      1185732     12/31/21  Northeast         Maine
# 8344       Amazon      1185732     12/31/21  Northeast         Maine
# 8345  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
#
#               city                product  price_per_unit  units_sold  \
# ...

# %%
# Check if any values are null.
Combined_data_df.isnull().values.any()
# Out:
# False

# %%
# Check the data type of each column
Combined_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9643 entries, 0 to 8345
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   retailer          9643 non-null   object
#  1   retailer_id       9643 non-null   int64
#  2   invoice_date      9643 non-null   object
#  3   region            9643 non-null   object
#  4   state             9643 non-null   object
#  5   city              9643 non-null   object
#  6   product           9643 non-null   object
#  7   price_per_unit    9643 non-null   int64
#  8   units_sold        9643 non-null   int64
#  9   total_sales       9643 non-null   int64
#  10  operating_profit  9643 non-null   float64
#  11  sales_method      9643 non-null   object
# dtypes: float64(1), int64(4), object(7)
# memory usage: 979.4+ KB

# %%
# Convert the "invoice_date" to a datetime datatype

Combined_data_df['invoice_date'] = Combined_data_df['invoice_date'].astype("datetime64[ns]")
# Out:
# C:\Users\jandr\AppData\Local\Temp\ipykernel_16376\3823125635.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   Combined_data_df['invoice_date'] = Combined_data_df['invoice_date'].astype("datetime64[ns]")

# %%
# Confirm that the "invoice_date" data type has been changed.
Combined_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9643 entries, 0 to 8345
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   retailer          9643 non-null   object
#  1   retailer_id       9643 non-null   int64
#  2   invoice_date      9643 non-null   datetime64[ns]
#  3   region            9643 non-null   object
#  4   state             9643 non-null   object
#  5   city              9643 non-null   object
#  6   product           9643 non-null   object
#  7   price_per_unit    9643 non-null   int64
#  8   units_sold        9643 non-null   int64
#  9   total_sales       9643 non-null   int64
#  10  operating_profit  9643 non-null   float64
#  11  sales_method      9643 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(4), object(6)
# memory usage: 979.4+ KB

# %% [markdown]
# ### 2. Determine which Region Sold the Most Products

# %% [markdown]
# #### Using `groupby`

# %%
# Show the number products sold for region, state, and city.
# Rename the sum to "Total_Products_Sold".
Total_products_df = Combined_data_df.groupby(["city", "state", "region"])["units_sold"].sum()
Total_products_df = Total_products_df.reset_index()
Total_products_df.head()

Total_products_df.sort_values(by='units_sold', ascending = False)
Total_Products_Sold = Total_products_df.sort_values(by='units_sold', ascending = False)

# Show the top 5 results.
Total_Products_Sold.head()
# Out:
#              city       state     region  units_sold
# 36       New York    New York  Northeast      111954
# 23        Houston       Texas      South       90322
# 48  San Francisco  California       West       85478
# 29    Los Angeles  California       West       76384
# 32          Miami     Florida  Southeast       73135

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the number products sold for region, state, and city.
pivot_table = pd.pivot_table(Total_Products_Sold, values="units_sold", index=["region"], aggfunc="sum")
pivot_table



# Rename the "units_sold" column to "Total_Products_Sold"
pivot_table.rename(columns={"units_sold": "total_products_sold"}, inplace=True)
pivot_table

# Show the top 5 results.
pivot_table.head(5)
# Out:
#            total_products_sold
# region
# Midwest                 390914
# Northeast               501279
# South                   492260
# Southeast               407000
# West                    685563

# %% [markdown]
# ### 3. Determine which Region had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each region, state, and city.
# Rename the "total_sales" column to "Total Sales"

Grouped_df = Combined_data_df.groupby(["city", "state", "region"])["total_sales"].sum().reset_index()
Grouped_df 
Grouped_df = Grouped_df.rename(columns={"total_sales": "Total Sales"})
Grouped_df

Grouped_df.sort_values(by='Total Sales', ascending = False)
# Show the top 5 results.
Grouped_df.head()
# Out:
#           city       state     region  Total Sales
# 0       Albany    New York  Northeast     24427804
# 1  Albuquerque  New Mexico       West     19865016
# 2    Anchorage      Alaska       West     14753103
# 3      Atlanta     Georgia  Southeast     18997466
# 4    Baltimore    Maryland  Northeast      7758059

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each region, state, and city.
pivot_table_1 = pd.pivot_table(Grouped_df, values="Total Sales", index=["region", "city", "state"], aggfunc="sum")
pivot_table_1


# Optional: Rename the "total_sales" column to "Total Sales"


# Show the top 5 results.
pivot_table_1.head(5)
# Out:
#                              Total Sales
# region  city       state
# Midwest Billings   Montana      15710886
#         Chicago    Illinois      9797488
#         Columbus   Ohio         18484583
#         Des Moines Iowa          7424011
#         Detroit    Michigan     18625433

# %%
pivot_table = pd.pivot_table(Total_Products_Sold, values="units_sold", index=["region"], aggfunc="sum")
pivot_table

# %% [markdown]
# ### 4. Determine which Retailer had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.
Total_sales_df = Combined_data_df.groupby(["retailer", "city", "state", "region"])["total_sales"].sum().reset_index()
Total_sales_df
# Rename the "total_sales" column to "Total Sales"

Total_sales_df.rename(columns={"total_sales": "Total Sales"})
# Show the top 5 results.
Total_sales_df.head()
# Out:
#   retailer        city           state     region  total_sales
# 0   Amazon   Anchorage          Alaska       West     13365025
# 1   Amazon  Birmingham         Alabama      South       409091
# 2   Amazon      Boston   Massachusetts  Northeast      4193590
# 3   Amazon  Burlington         Vermont  Northeast     13380463
# 4   Amazon   Charlotte  North Carolina  Southeast      3733676

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.
pivot_table_2 = pd.pivot_table(Total_sales_df, values="total_sales", index=["retailer", "region", "city", "state"], aggfunc="sum")
pivot_table_2



# Optional: Rename the "total_sales" column to "Total Sales"


# Show the top 5 results.
pivot_table_2.head()
# Out:
#                                              total_sales
# retailer region    city       state
# Amazon   Midwest   Columbus   Ohio              16835873
#          Northeast Boston     Massachusetts      4193590
#                    Burlington Vermont           13380463
#                    Manchester New Hampshire     10077142
#                    Portland   Maine              8611395

# %% [markdown]
# ### 5. Determine which Retailer Sold the Most Women's Athletic Footwear

# %%
# Filter the sales data to get the women's athletic footwear sales data.
Combined_data_df
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0     Foot Locker      1185732       1/1/20  Northeast      New York
# 1     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3     Foot Locker      1185732       1/1/20  Northeast      New York
# 4     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 8341  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 8342  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 8343       Amazon      1185732     12/31/21  Northeast         Maine
# 8344       Amazon      1185732     12/31/21  Northeast         Maine
# 8345  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
#
#               city                product  price_per_unit  units_sold  \
# ...

# %%
Combined_data_df["product"]
# Out:
# 0       Men's Street Footwear
# 1             Women's Apparel
# 2             Women's Apparel
# 3       Men's Street Footwear
# 4             Women's Apparel
#                 ...
# 8341            Men's Apparel
# 8342            Men's Apparel
# 8343            Men's Apparel
# 8344            Men's Apparel
# 8345            Men's Apparel
# Name: product, Length: 9643, dtype: object

# %%
Combined_data_df[Combined_data_df["product"] == "women's athletic footwear"]
# Out:
# Empty DataFrame
# Columns: [retailer, retailer_id, invoice_date, region, state, city, product, price_per_unit, units_sold, total_sales, operating_profit, sales_method]
# Index: []

# %%
Combined_data_df["product"].unique()
# Out:
# array(["Men's Street Footwear", "Women's Apparel",
#        "Men's Athletic Footwear", "Women's Street Footwear",
#        "Women's Athletic Footwear", "Men's Apparel"], dtype=object)

# %%
Womens_footwear_df = Combined_data_df[Combined_data_df["product"] == "Women's Athletic Footwear"]
Womens_footwear_df
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 21    Foot Locker      1185732       1/4/20  Northeast      New York
# 22    Foot Locker      1185732       1/4/20  Northeast      New York
# 23    Foot Locker      1185732       1/4/20  Northeast      New York
# 26      West Gear      1128299       1/5/20  Northeast  Pennsylvania
# 27      West Gear      1128299       1/5/20  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 8336  Foot Locker      1185732     12/30/21  Northeast  Pennsylvania
# 8337  Foot Locker      1185732     12/30/21  Northeast  Pennsylvania
# 8338       Amazon      1185732     12/30/21  Northeast         Maine
# 8339       Amazon      1185732     12/30/21  Northeast         Maine
# 8340  Foot Locker      1185732     12/30/21  Northeast  Pennsylvania
#
#               city                    product  price_per_unit  units_sold  \
# ...

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.

Total_womens_footwear_sold_df = Womens_footwear_df.groupby(["retailer", "city", "state", "region"])["units_sold"].sum().reset_index()
Total_womens_footwear_sold_df
# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"
Total_womens_footwear_sold_df = Total_womens_footwear_sold_df.rename(columns={"units_sold": "Womens_Footwear_Units_Sold"})

# Show the top 5 results.
Total_womens_footwear_sold_df.head()
# Out:
#   retailer        city           state     region  Womens_Footwear_Units_Sold
# 0   Amazon   Anchorage          Alaska       West                        2810
# 1   Amazon  Birmingham         Alabama      South                         158
# 2   Amazon      Boston   Massachusetts  Northeast                        1190
# 3   Amazon  Burlington         Vermont  Northeast                        4327
# 4   Amazon   Charlotte  North Carolina  Southeast                        1419

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.
pivot_table_3 = pd.pivot_table(Total_womens_footwear_sold_df, values="Womens_Footwear_Units_Sold", index=["retailer", "region", "city", "state"], aggfunc="sum")
pivot_table_3

# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"


# Show the top 5 results.
pivot_table_3.head()
# Out:
#                                              Womens_Footwear_Units_Sold
# retailer region    city       state
# Amazon   Midwest   Columbus   Ohio                                 5801
#          Northeast Boston     Massachusetts                        1190
#                    Burlington Vermont                              4327
#                    Manchester New Hampshire                        3109
#                    Portland   Maine                                1841

# %% [markdown]
# ### 6. Determine the Day with the Most Women's Athletic Footwear Sales

# %%
# Create a pivot table with the 'invoice_date' column is the index, and the "total_sales" as the values.
pivot_table_4 = pd.pivot_table(Womens_footwear_df, values="total_sales", index=["invoice_date"], aggfunc="sum")
pivot_table_4


# Optional: Rename the "total_sales" column to "Total Sales"


# Show the table.
# Out:
#               total_sales
# invoice_date
# 1/10/21            315859
# 1/11/20            129556
# 1/11/21             66584
# 1/12/21            405693
# 1/13/21            256764
# ...                   ...
# 9/6/21             103419
# 9/7/21             241024
# 9/8/20             726106
# 9/8/21             242278
# 9/9/21             388630
#
# [355 rows x 1 columns]

# %%
# Resample the pivot table into daily bins, and get the total sales for each day.

pivot_table_5 = pivot_table_4.groupby(["invoice_date"]).sum()

pivot_table_5
# Sort the resampled pivot table in descending order on "Total Sales".
# Out:
#               total_sales
# invoice_date
# 1/10/21            315859
# 1/11/20            129556
# 1/11/21             66584
# 1/12/21            405693
# 1/13/21            256764
# ...                   ...
# 9/6/21             103419
# 9/7/21             241024
# 9/8/20             726106
# 9/8/21             242278
# 9/9/21             388630
#
# [355 rows x 1 columns]

# %%
Womens_footwear_df["invoice_date"] = pd.to_datetime(Womens_footwear_df["invoice_date"])
pivot_table_4 = pd.pivot_table(
    Womens_footwear_df,
    values="total_sales",
    index="invoice_date",
    aggfunc="sum"
)
pivot_table_4
# Out:
# C:\Users\jandr\AppData\Local\Temp\ipykernel_16376\2862435003.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Womens_footwear_df["invoice_date"] = pd.to_datetime(Womens_footwear_df["invoice_date"])
#               total_sales
# invoice_date
# 2020-01-04         402743
# 2020-01-05         141801
# 2020-01-11         129556
# 2020-01-17         173013
# 2020-01-22         388250
# ...                   ...
# 2021-12-22         200406
# 2021-12-23         808022
# 2021-12-24         190885
# 2021-12-25         315175
# 2021-12-30         167903
#
# [355 rows x 1 columns]

# %% [markdown]
# ### 7.  Determine the Week with the Most Women's Athletic Footwear Sales

# %%
# Resample the pivot table into weekly bins, and get the total sales for each week.

weekly_sales = pivot_table_4.resample('W').sum()
weekly_sales
# Sort the resampled pivot table in descending order on "Total Sales".
resampled_by_sales = weekly_sales.sort_values(by='total_sales', ascending = False)
resampled_by_sales
# Out:
#               total_sales
# invoice_date
# 2021-12-19        3098970
# 2021-12-12        2922161
# 2021-07-11        2835078
# 2021-07-18        2801449
# 2021-11-14        2531721
# ...                   ...
# 2020-12-06          62801
# 2020-12-20          61710
# 2020-12-13          58916
# 2020-11-22          53940
# 2020-10-18              0
#
# [105 rows x 1 columns]
